# %%
import os
import pandas as pd
import numpy as np
import json

# %%
wyscout_path = '/home/greg/Documents/football/data/wyscout'
with open(os.path.join(wyscout_path, 'events/events_England.json')) as f:
    data = json.load(f)

# %%
wyscout_path = '/home/greg/Documents/football/data/wyscout'
with open(os.path.join(wyscout_path, 'events/events_England.json')) as f:
    data = json.load(f)
    
#Create a data set of shots.
data = pd.DataFrame(data)

# %%
shots = data[data["subEventName"]=="Shot"]
shots[]
# Out:
#         eventId subEventName  \
# 46           10         Shot
# 62           10         Shot
# 91           10         Shot
# 128          10         Shot
# 249          10         Shot
# ...         ...          ...
# 642945       10         Shot
# 643023       10         Shot
# 643051       10         Shot
# 643055       10         Shot
# 643149       10         Shot
#
#                                                      tags  playerId  \
# 46      [{'id': 101}, {'id': 402}, {'id': 201}, {'id':...     25413
# 62      [{'id': 401}, {'id': 201}, {'id': 1211}, {'id'...     26150
# 91      [{'id': 101}, {'id': 403}, {'id': 201}, {'id':...     14763
# 128     [{'id': 401}, {'id': 201}, {'id': 1215}, {'id'...      7868
# 249     [{'id': 402}, {'id': 201}, {'id': 1205}, {'id'...      7868
# ...                                                   ...       ...
# 642945          [{'id': 401}, {'id': 1212}, {'id': 1802}]      8561
# ...
